# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовительный-этап" data-toc-modified-id="Подготовительный-этап-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовительный этап</a></span><ul class="toc-item"><li><span><a href="#Изучение-общей-информации,-составление-плана-работы" data-toc-modified-id="Изучение-общей-информации,-составление-плана-работы-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Изучение общей информации, составление плана работы</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Исследовательских-анализ-данных" data-toc-modified-id="Исследовательских-анализ-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Исследовательских анализ данных</a></span></li><li><span><a href="#Портрет-пользователя-каждого-региона" data-toc-modified-id="Портрет-пользователя-каждого-региона-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Портрет пользователя каждого региона</a></span></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Проверка гипотез</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></li><li><span><a href="#Изучение-общей-информации" data-toc-modified-id="Изучение-общей-информации-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение общей информации</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Заменить-названия-столбцов" data-toc-modified-id="Заменить-названия-столбцов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Заменить названия столбцов</a></span></li><li><span><a href="#Обработать-пропуски" data-toc-modified-id="Обработать-пропуски-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обработать пропуски</a></span></li><li><span><a href="#Преобразовать-данные-в-нужные-типы" data-toc-modified-id="Преобразовать-данные-в-нужные-типы-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Преобразовать данные в нужные типы</a></span></li><li><span><a href="#Посчитать-суммарные-продажи-по-регионам-и-записать-в-отдельный-столбец" data-toc-modified-id="Посчитать-суммарные-продажи-по-регионам-и-записать-в-отдельный-столбец-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Посчитать суммарные продажи по регионам и записать в отдельный столбец</a></span></li><li><span><a href="#Промежуточный-вывод" data-toc-modified-id="Промежуточный-вывод-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Промежуточный вывод</a></span></li></ul></li><li><span><a href="#Исследовательских-анализ-данных" data-toc-modified-id="Исследовательских-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательских анализ данных</a></span><ul class="toc-item"><li><span><a href="#Сколько-игр-выпускалось-в-разные-годы.-Выбор-периодов-для-исследования." data-toc-modified-id="Сколько-игр-выпускалось-в-разные-годы.-Выбор-периодов-для-исследования.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Сколько игр выпускалось в разные годы. Выбор периодов для исследования.</a></span></li><li><span><a href="#Изменения-продаж-по-платформам-с-течением-времени" data-toc-modified-id="Изменения-продаж-по-платформам-с-течением-времени-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изменения продаж по платформам с течением времени</a></span></li><li><span><a href="#Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выбрать-несколько-потенциально-прибыльных-платформ." data-toc-modified-id="Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выбрать-несколько-потенциально-прибыльных-платформ.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Какие платформы лидируют по продажам, растут или падают? Выбрать несколько потенциально прибыльных платформ.</a></span></li><li><span><a href="#График-&quot;ящик-с-усами&quot;-по-глобальным-продажам-игр-в-разбивке-по-платформам." data-toc-modified-id="График-&quot;ящик-с-усами&quot;-по-глобальным-продажам-игр-в-разбивке-по-платформам.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>График "ящик с усами" по глобальным продажам игр в разбивке по платформам.</a></span></li><li><span><a href="#Оценим-влияние-отзывов-пользователей-и-критиков-на-продажи-внутри-одной-популярной-платформы" data-toc-modified-id="Оценим-влияние-отзывов-пользователей-и-критиков-на-продажи-внутри-одной-популярной-платформы-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Оценим влияние отзывов пользователей и критиков на продажи внутри одной популярной платформы</a></span></li><li><span><a href="#Соотнесем-выводы-с-продажами-игр-на-других-платформах" data-toc-modified-id="Соотнесем-выводы-с-продажами-игр-на-других-платформах-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Соотнесем выводы с продажами игр на других платформах</a></span></li><li><span><a href="#Оценим-распределение-игр-по-жанрам.-Какие-жанры-самые-прибыльные?-Выделяются-ли-жанры-с-высокими-и-низкими-продажами?" data-toc-modified-id="Оценим-распределение-игр-по-жанрам.-Какие-жанры-самые-прибыльные?-Выделяются-ли-жанры-с-высокими-и-низкими-продажами?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Оценим распределение игр по жанрам. Какие жанры самые прибыльные? Выделяются ли жанры с высокими и низкими продажами?</a></span></li></ul></li><li><span><a href="#Портрет-пользователя-каждого-региона" data-toc-modified-id="Портрет-пользователя-каждого-региона-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Портрет пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Самые-популярные-платформы-(топ-5).-Различия-в-долях-продаж." data-toc-modified-id="Самые-популярные-платформы-(топ-5).-Различия-в-долях-продаж.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Самые популярные платформы (топ-5). Различия в долях продаж.</a></span></li><li><span><a href="#Самые-популярные-жанры-(топ-5)." data-toc-modified-id="Самые-популярные-жанры-(топ-5).-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Самые популярные жанры (топ-5).</a></span></li><li><span><a href="#Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе?" data-toc-modified-id="Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе?-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Влияет ли рейтинг ESRB на продажи в отдельном регионе?</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Средние-пользовательские-рейтинги-платформ-Xbox-One-и-РС-одинаковые;" data-toc-modified-id="Средние-пользовательские-рейтинги-платформ-Xbox-One-и-РС-одинаковые;-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Средние пользовательские рейтинги платформ Xbox One и РС одинаковые;</a></span></li><li><span><a href="#Средние-пользовательские-рейтинги-жанров-Action-и-Sports-разные" data-toc-modified-id="Средние-пользовательские-рейтинги-жанров-Action-и-Sports-разные-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Средние пользовательские рейтинги жанров Action и Sports разные</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Сборный проект
#
# ## Подготовительный этап

# %% [markdown]
# ### Изучение общей информации, составление плана работы
# 1. Открем датасет
# 2. Посмотрим, какие есть столбцы и какого они типа
# 3. Напишем промежуточный вывод: какие основные типы, а так же заметны ли пропуски в датасете
# 4. Распишем весь план работ
# 5. Опишем план и сделаем соответствующие параграфы в тетрадке
#
# ### Подготовка данных
# 1. Заменить названия столбцов
# 2. Преобразовать данные в нужные типы
# 3. Обработать пропуски
#   * Объяснить способы заполнения пропусков
#   * Описать причины появления пропусков
#   * Описать подход к значениям "tbd"
# 4. Посчитать суммарные продажи по регионам и записать в отдельный столбец
#
# ### Исследовательских анализ данных
# 1. Сколько игр выпускалось в разные годы.
#   * Выбор периодов для исследования.
# 2. Изменения продаж по платформам с течением времени.
#   * Выбор платформ с наибольшими суммарными продажами.
#   * Гистограмма распределения по годам.
#   * За какой характерный срок появляются новые и исчезают старые платформы?
# 3. Возьмем данные за актуальный период (который позволят построить прогноз на 2017 год).
#   * Данные за предыдущие года не учитываем.
# 4. Какие платформы лидируют по продажам, растут или падают? Выбрать несколько потенциально прибыльных платформ.
# 5. График "ящик с усами" по глобальным продажам игр в разбивке по платформам.
# 6. Оценить влияение отзывов пользователей и критиков на продажи внутри одной популярной платформы.
#   * Построить диаграмму рассеяния и посчитать кореляцию: отзывы-продажи.
# 7. Соотнести вывода с продажами игр на других платформах.
# 8. Оценить распределение игр по жанрам. Какие жанры самые прибыльные? Выделяются ли жанры с высокими и низкими продажами?
#
# ### Портрет пользователя каждого региона
# Для пользователя из Северной Америки, Европы, Японии и других стран.
# 1. Самые популярные платформы (топ-5). Различия в долях продаж.
# 2. Самые популярные жанры (топ-5).
# 3. Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# ### Проверка гипотез
# 1. Средние пользовательские рейтинги платформ Xbox One и РС одинаковые;
# 2. Средние пользовательские рейтинги жанров Action и Sports разные.
#
# ### Общий вывод
# Выявить закономерности, определяющие успешность игры, чтобы сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.

# %% [markdown]
# ## Изучение общей информации

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats as st
from sklearn import preprocessing
from IPython.display import display_html

# %matplotlib inline
sns.set_style('darkgrid')

# %%
try:
    df = pd.read_csv('datasets/games.csv')
except FileNotFoundError:
    df = pd.read_csv('../../datasets/games.csv')

# %%
print(f'Размер датасета {df.shape}')
df.head()
# Out:
# Размер датасета (16715, 11)
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %%
len(df['Name'].unique())
# Out:
# 11560

# %% [markdown]
# Уникальных игр меньше, чем записей в таблице. Значит, некоторые игры выпускались на нескольких платформах.
#
# Посмотрим кстати, какие платформы у нас представлены.

# %%
df['Platform'].value_counts()
# Out:
# PS2     2161
# DS      2151
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      430
# PS4      392
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       29
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
df['Genre'].value_counts()
# Out:
# Action          3369
# Sports          2348
# Misc            1750
# Role-Playing    1498
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       873
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: Genre, dtype: int64

# %%
df['Rating'].value_counts()
# Out:
# E       3990
# T       2961
# M       1563
# E10+    1420
# EC         8
# K-A        3
# RP         3
# AO         1
# Name: Rating, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Вывод
# * Датасет имеет размер 16715 строк и 11 столбцов.
# * В некоторых столбцах необходимо поменять тип данных.
# * В числовых столбцах аномалий нет, данные выглядят правдоподобно.
# * Категориальные значения тоже выглядят приемлимо.
# * Явных дубликатов в данных нет.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Заменить названия столбцов

# %% [markdown]
# Названия столбцов нас устраивают, поэтому просто приведём их к нижнему регистру.

# %%
df.columns = df.columns.str.lower()

# %% [markdown]
# ### Обработать пропуски
#   * Объяснить способы заполнения пропусков
#   * Описать причины появления пропусков
#   * Описать подход к значениям "tbd"

# %%
df['user_score'] = df['user_score'].replace('tbd', np.nan)

# %% [markdown]
# **Пропуски в столбце `name`**

# %%
df.loc[df['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# Удалим эти 2 строки.

# %%
df.loc[df['critic_score'].isna()].head(10)
# Out:
#                              name platform  year_of_release         genre  \
# 1               Super Mario Bros.      NES           1985.0      Platform
# 4        Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                          Tetris       GB           1989.0        Puzzle
# 9                       Duck Hunt      NES           1984.0       Shooter
# 10                     Nintendogs       DS           2005.0    Simulation
# 12    Pokemon Gold/Pokemon Silver       GB           1999.0  Role-Playing
# 18              Super Mario World     SNES           1990.0      Platform
# 20  Pokemon Diamond/Pokemon Pearl       DS           2006.0  Role-Playing
# 21               Super Mario Land       GB           1989.0      Platform
# 22            Super Mario Bros. 3      NES           1988.0      Platform
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score user_score rating
# ...

# %%
df = df.dropna(subset=['name', 'year_of_release']).reset_index(drop=True)

# %%
print('Пропуски в столбце "critic_score":', df.loc[df['critic_score'].isna()].shape[0])

print('Пропуски в столбце "user_score":', df.loc[df['user_score'].isna()].shape[0])

print('Пропуски в обоих столбцах сразу:', df.loc[df['critic_score'].isna() & df['user_score'].isna()].shape[0])
# Out:
# Пропуски в столбце "critic_score": 8461
# Пропуски в столбце "user_score": 8981
# Пропуски в обоих столбцах сразу: 7892

# %%
df.loc[df['critic_score'].isna() & df['user_score'].isna()]['year_of_release'].describe()
# Out:
# count    7892.000000
# mean     2005.506336
# std         7.102386
# min      1980.000000
# 25%      2000.000000
# 50%      2008.000000
# 75%      2010.000000
# max      2016.000000
# Name: year_of_release, dtype: float64

# %% [markdown]
# Пропуски с годом не связаны, так как они есть в играх с 1980 по 2016 год, как и весь остальной датасет.
#
# **Пропуски в рейтинге ESRB** заполним заглушкой "not used", потому что во многих регионах рейтинг действительно не присваивается

# %%
df['rating'].fillna('not_used', inplace=True)

# %% [markdown]
# ### Преобразовать данные в нужные типы

# %% [markdown]
# * Столбец `year` приведем к целочисленнному типу.
# * `platform`, `genre`, `rating` преобразуем в категориальный тип.
# * `user_score` в вещественный
#
# *По ходу работы над проектом пришлось отказаться от преобразования столбцов "платформа" и "рейтинг" в категориальный тип, так как некорректно отображались графики*

# %%
# df['platform'] = df['platform'].astype('category')
df['genre'] = df['genre'].astype('category')
# df['rating'] = df['rating'].astype('category')
df['user_score'] = df['user_score'].astype('float')
df['year_of_release'] = df['year_of_release'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16444 entries, 0 to 16443
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int32
#  3   genre            16444 non-null  category
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       7463 non-null   float64
#  10  rating           16444 non-null  object
# dtypes: category(1), float64(6), int32(1), object(3)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Посчитать суммарные продажи по регионам и записать в отдельный столбец

# %%
df['sum_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %% [markdown]
# ### Промежуточный вывод
# * В столбце `user_score` заменили значения "tbd" на NaN
#   * значение "tbd" это аббревиатура от To Be Determined ("будет определено"), так что, вероятно, в этих наблюдениях оценки пользователей еще ожидаются - в текущих данных их нет.
# * Строки с пропусками в столбцах `name` и `year_of_release` просто удалили, так как их относительно мало в нашем датасете.
# * Около половины всех строк у нас с пропусками в `user_score` и `critic_score`, так много удалить мы не можем - будем работать с тем, что есть.
# * Добавили столбец `sum_sales` с суммарными продажами каждой игры во всех регионах.

# %% [markdown]
# ## Исследовательских анализ данных

# %% [markdown]
# ### Сколько игр выпускалось в разные годы. Выбор периодов для исследования.

# %%
plt.figure(dpi=120)
sns.histplot(
    df['year_of_release'],
    bins=37   
)
plt.ylabel('Количество новых игр', fontsize=14)
plt.xlabel('Год выпуска', fontsize=14)
plt.title('Количество новых игр в год', fontsize=16);

# %% [markdown]
# **Вывод**
# * Период до 1995 года нам не интересен, выпускалось совсем мало игр.
# * Наибольшее количество игр выходило **в период с 2005 по 2011 год**.
# * А вот с 2012 года количество новых игр резко сократилось примерно в 2 раза.
# * В качестве **актуального периода для наших целей периода возьмем игры 2014 года выпуска и позже.**

# %% [markdown]
# ### Изменения продаж по платформам с течением времени
#   * Выбор платформ с наибольшими суммарными продажами.
#   * Гистограмма распределения по годам.
#   * За какой характерный срок появляются новые и исчезают старые платформы?
#
# Для ответа на эти вопросы поработаем пока что с датасетом целиком.
# Посмотрим сперва на самые топовые платформы **всех времён** (в рамках датасета: 1980-2016 гг).
#
# Создадим сводную таблицу, где в качестве индексов `platform` и построим по ней гистограмму, чтобы отобрать топовые платформы для дальнейшего анализа.

# %%
alltime_top_platforms = df.pivot_table(index='platform', 
                                    values='sum_sales', aggfunc='sum'
                                 ).sort_values(by='sum_sales', ascending=False)

plt.figure(dpi=120)
plt.bar(x=alltime_top_platforms.index, height=alltime_top_platforms['sum_sales'])
plt.title("Продажи по платформам за все годы")
plt.xlabel("Название платформы")
plt.xticks(rotation=90)
plt.ylabel("Сумма продаж");

# %% [markdown]
# Сразу можем заметить, что есть топ-6 по популярности платформ:
# * PS2 - хит всех времён, более 1.2 млрд проданных копий игр
# * X360
# * PS3
# * Wii
# * DS
# * PS

# %%
top_6_platforms = list(alltime_top_platforms.reset_index().head(6)['platform'])
top_6_platforms
# Out:
# ['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS']

# %% [markdown]
# Для оценки времени жизни платформы посмотрим на динамику продаж для шести наиболее популярных платформ всех времен.

# %%
plt.figure(figsize=(12, 7))
plt.grid(True)
plt.title('Количество продаж для популярных игровых платформ', fontsize=16)
plt.xlabel('Годы игровых релизов')
plt.ylabel('Сумма продаж')

# строим линейные графики сумма продаж - год релиза для каждой платформы
sns.lineplot(
    data=df.query('platform.isin(@top_6_platforms)'),
    x='year_of_release',
    y='sum_sales',
    hue='platform',
    estimator='sum',
    ci=None
);

# %% [markdown]
# **Вывод**
# * Приставки PlayStation чётко сменяли друг друга от поколения к поколению, время жизни оставалось примерно одинаковым (8-10 лет), однако есть тенденция к сокращению времени жизни платформы.
# * Пик популярности приставок всех производителей приходится на 2008-2011 года и наступает спустя 5 лет после запуска платформы.
# * К 2015-2016 году нет ни одной платформы, которую можно было бы назвать популярной.
# * Этот факт логично объясняется тем, что со второй декады 21 века активно начали развиваться игры для мобильных платформ (телефонов, планшетов и т.д.)
# * По этим графикам также можем предположить среднее время жизни платформы: 6-8 лет
#
# Оценим среднее время жизни платформы более точно, рассчитав среднее значение для всех платформ:

# %%
df_lifetime = df.pivot_table(
                index='platform', aggfunc={'year_of_release': ['min', 'max']}).reset_index()
df_lifetime['years_of_life'] = df_lifetime[('year_of_release', 'max')] - df_lifetime[('year_of_release', 'min')]

print('Среднее время жизни платформы', round(df_lifetime['years_of_life'].mean(), 1), 'лет')
# Out:
# Среднее время жизни платформы 7.6 лет

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают? Выбрать несколько потенциально прибыльных платформ.
#
# Чтобы выбрать платформы, которые могут принести прибыль в 2017 году, будем опираться на дату запуска платформы в периоде 2014-2016 годы, потому что:
# * Пик количества продаж у платформы еще не наступил
# * Есть несколько лет до окончания популярности
# * Рынок компьютерных игр очень динамичен, данные старше 3-х лет уже не актуальны

# %% [markdown]
# **Далее в работе будем использовать срез датасета только за актуальный период, то есть, после 2014 года.**

# %%
# берем актуальные данные - релизы свежее 2014 года и платформы из топ-6 по сумме продаж
df_actual = df.query('year_of_release >= 2014')

# %%
plt.figure(figsize=(12,7), dpi=150)
plt.grid(True)
plt.title('Количество продаж для потенциально прибыльных платформ', fontsize=18)
plt.xlabel('Годы игровых релизов', fontsize=16)
plt.ylabel('Сумма продаж', fontsize=16)
sns.lineplot(
    data=df_actual,
    x='year_of_release',
    y='sum_sales',
    hue='platform',
    estimator='sum',
    ci=None
);

# %% [markdown]
# **Вывод**
# * Ситуация с игровыми платформами к 2016 году максимально печальная:
#     * В этом временном периоде лидируют по продажам PS4 и XOne, потому что они только появились в 2013-2014 годах, однако и они уже прошли свой пик продаж и близятся к плато.
#     * К 2016 году упали продажи для всех платформ, поэтому **выделить потенциально прибыльные в 2017 году не представляется возможным**.

# %% [markdown]
# ### График "ящик с усами" по глобальным продажам игр в разбивке по платформам.

# %%
# возьмем топ-7 платформ по количеству продаж после 2011 года
pp_top7_platform = (df_actual
                    .groupby('platform')['sum_sales'].sum()
                    .sort_values(ascending=False)
                    .head(7).index)
pp_top7_platform
# Out:
# Index(['PS4', 'XOne', '3DS', 'PS3', 'X360', 'WiiU', 'PC'], dtype='object', name='platform')

# %%
plt.figure(figsize=(22,10), dpi=150)
plt.grid(True)

sns.boxplot(
    data=df_actual[df_actual['platform'].isin(pp_top7_platform)],
    y='platform',
    x='sum_sales'
)
plt.title('Распределение суммы продаж у разных платформ', fontsize=22)
plt.xlabel('Сумма продаж', fontsize=18)
plt.ylabel('Игровая платформа', fontsize=18);

# %%
plt.figure(figsize=(22,10), dpi=150)
plt.grid(True)

sns.boxplot(
    data=df_actual[df_actual['platform'].isin(pp_top7_platform)],
    y='platform',
    x='sum_sales'
)
plt.xlim([0,2])
plt.title('Распределение суммы продаж у разных платформ', fontsize=22)
plt.xlabel('Сумма продаж', fontsize=18)
plt.ylabel('Игровая платформа', fontsize=18);

# %%
df_actual.sort_values(by='sum_sales', ascending=False).head(3)
# Out:
#                                          name platform  year_of_release  \
# 31                  Call of Duty: Black Ops 3      PS4             2015
# 42                         Grand Theft Auto V      PS4             2014
# 47  Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS             2014
#
#            genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 31       Shooter      6.03      5.86      0.36         2.38           NaN
# 42        Action      3.96      6.31      0.38         1.97          97.0
# 47  Role-Playing      4.35      3.49      3.10         0.74           NaN
#
#     user_score    rating  sum_sales
# 31         NaN  not_used      14.63
# 42         8.3         M      12.62
# 47         NaN  not_used      11.68

# %% [markdown]
# **Вывод**
# * Мы построили график "ящик с усами" для семи платформ с наибольшей суммой продаж в последние годы.
# * Лидерами определенно можно считать платформы от Sony и Microsoft *(чуть-чуть отстает WiiU от Nintendo)*
# * По медианной сумме продаж наилучшие результаты показали приставки от Microsoft (XOne и X360).
# * Наиболее успешные игры, которые мы видим как выбросы, это:
#     * Call of Duty: Black Ops 3 и GTA V **для PS4**
#     * Pokemon Omega Ruby/Pokemon Alpha Sapphire **для 3DS**

# %% [markdown]
# ### Оценим влияние отзывов пользователей и критиков на продажи внутри одной популярной платформы
#   * В качестве популярной платформы возьмем PS4 от Sony.
#   * Построим диаграмму рассеяния и посчитаем кореляцию: отзывы-продажи.

# %%
df_ps4 = df_actual.query('platform == "PS4"')
print('Доля пропущенных значений в оценках критиков для игр на PS4 {:.1%}'.format(
    df_ps4['critic_score'].isna().sum() / df_ps4.shape[0]))
print('Доля пропущенных значений в оценках пользователей для игр на PS4 {:.1%}'.format(
    df_ps4['user_score'].isna().sum() / df_ps4.shape[0]))
# Out:
# Доля пропущенных значений в оценках критиков для игр на PS4 37.0%
# Доля пропущенных значений в оценках пользователей для игр на PS4 35.6%

# %% [markdown]
# * Что ж, около трети игр у нас не имеют оценки пользователей или критиков, будем работать с оставшимися данными.
# * `critic_score` и `user_score` имеют распределения разных порядков, поэтому на один график их не поместить.

# %%
def user_critic_scatter(platform):
    df_platform = df_actual.query('platform == @platform')
    fig, ax = plt.subplots(1,2, figsize=(16, 6))
    fig.suptitle(f'Зависимость продаж от оценок критиков и пользователей для платформы {platform}', fontsize=20)
    
    ax1 = sns.scatterplot(
        data=df_platform,
        x='sum_sales',
        y='critic_score',
        ax=ax[0])
    ax1.set_title('Зависимость суммы продаж от оценки критиков', fontsize=15)
    ax1.set_xlabel('Сумма продаж', fontsize=16)
    ax1.set_ylabel('Оценки критиков', fontsize=16)

    ax2 = sns.scatterplot(
        data=df_platform,
        x='sum_sales',
        y='user_score',
        ax=ax[1]);
    ax2.set_title('Зависимость суммы продаж от оценки пользователей', fontsize=15)
    ax2.set_xlabel('Сумма продаж', fontsize=16)
    ax2.set_ylabel('Оценки пользователей', fontsize=16);
    sns.set_style('darkgrid')

    print(f'Корреляция между продажами и оценкой критиков для платформы {platform}',
          round(df_platform['sum_sales'].corr(df_platform['critic_score']), 3))
    print(f'Корреляция между продажами и оценкой пользователей для платформы {platform}',
          round(df_platform['sum_sales'].corr(df_platform['user_score']), 3))

user_critic_scatter('PS4')
# Out:
# Корреляция между продажами и оценкой критиков для платформы PS4 0.403
# Корреляция между продажами и оценкой пользователей для платформы PS4 -0.04

# %% [markdown]
# **Вывод**
# * Присутствует слабая положительная корреляция между оценками критиков и продажами
# * Корреляция между оценками пользователей и продажами отсутствует

# %% [markdown]
# ### Соотнесем выводы с продажами игр на других платформах
#
# Посмотрим те же самые распределения для других популярных плафторм из нашего топ-7, например:
# * 'XOne',
# * '3DS'
# * 'PS3'

# %%
user_critic_scatter('XOne')
user_critic_scatter('3DS')
user_critic_scatter('PS3')
# Out:
# Корреляция между продажами и оценкой критиков для платформы XOne 0.429
# Корреляция между продажами и оценкой пользователей для платформы XOne -0.07
# Корреляция между продажами и оценкой критиков для платформы 3DS 0.314
# Корреляция между продажами и оценкой пользователей для платформы 3DS 0.215
# Корреляция между продажами и оценкой критиков для платформы PS3 0.447
# Корреляция между продажами и оценкой пользователей для платформы PS3 -0.167

# %% [markdown]
# **Вывод**
# * Предыдущий вывод можно экстраполировать и для этих платформ:
#     * Корреляция с оценками критиков слабая положительная
#     * Корреляция с оценками пользователей отсутствует

# %% [markdown]
# ### Оценим распределение игр по жанрам. Какие жанры самые прибыльные? Выделяются ли жанры с высокими и низкими продажами?

# %%
df_actual.pivot_table(index='genre', values='name', aggfunc='count').sort_values(by='name', ascending=False)
# Out:
#               name
# genre
# Action         619
# Role-Playing   221
# Adventure      185
# Sports         161
# Shooter        128
# Misc           113
# Racing          69
# Fighting        60
# Simulation      44
# Platform        38
# Strategy        37
# Puzzle          14

# %% [markdown]
# **Экшн, РПГ и приключения** - 3 наиболее популярных жанра, в которых выпускается наибольшее количество игр.
#
# Теперь посмотрим на продажи: однако, нам нужно как-то нормализовать суммарные продажи, потому что игр разных жанров выпускалось разное количество, соответственно и сумма продаж будет больше у жанров с бОльшим количеством игр. Используем для этого среднее значение продаж в сводной таблице.

# %%
df_actual.pivot_table(index='genre', aggfunc={'sum_sales':['mean', 'median']}).sort_values(by=('sum_sales','median'), ascending=False)
# Out:
#              sum_sales
#                   mean median
# genre
# Shooter       1.335469  0.515
# Sports        0.680000  0.180
# Platform      0.476053  0.140
# Fighting      0.470333  0.125
# Role-Playing  0.459005  0.110
# Simulation    0.298409  0.100
# Action        0.322068  0.090
# Misc          0.332301  0.090
# Racing        0.398841  0.090
# Strategy      0.107027  0.060
# Puzzle        0.157857  0.045
# Adventure     0.094865  0.030

# %% [markdown]
# **Вывод**
# * Оцениваем прибыльность жанра по **по среднему и медианному количеству проданных копий**:
#     * **Первое место** заслуженно занимают **шутеры**, сразу можно вспомнить множество популярных игр (Left 4 Dead, Half-life, Far Cry, Counter-Strike и т.д.) - почти 1 млн копий продано на каждую выпущенную игру;
#     * На **втором месте жанр спортивных игр**;
#     * **Третье место у платформеров**.
# * Наименее прибыльные жанры: паззлы, приключения и стратегия
#
#
# *Кроме платформеров выводы не удивляют - шутеры и спортивные игры действительно очень увлекательны и не дают игрокам оторваться от процесса: в обоих этих жанрах присутствует постоянное напряжение в игровом процессе и соревновательный элемент.*

# %%
plt.figure(figsize=(18,14))
plt.grid(True)

sns.boxplot(
    data=df_actual,
    y='genre',
    x='sum_sales'
)
plt.xlim([0,4])
plt.title('Диаграмма размаха для суммы продаж по жанрам', fontsize=22)
plt.xlabel('Сумма продаж', fontsize=18)
plt.ylabel('Жанр', fontsize=18);

# %% [markdown]
# **Оценка жанров по медиане**
#
# * Здесь мы видим такую же тройку лидеров: Shooter, Sports, Platform.
# * При том **шутеры в разы популярнее других жанров** по обоим показателям: и по медиане, и по третьему квартилю.

# %% [markdown]
# ## Портрет пользователя каждого региона
# Для пользователя из Северной Америки, Европы, Японии и других стран.

# %% [markdown]
# ### Самые популярные платформы (топ-5). Различия в долях продаж.

# %% [markdown]
# Здесь мы будем выводить маленькие сводные таблички, поэтому удобно будет взглянуть на них рядом. Для этого удалось найти функцию, написанную добрым человеком, которая выводит несколько таблиц в одном ряду.

# %%
def display_side_by_side(*args):
    html_str=' '
    for df in args:
        html_str+=df.to_html()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

# %% [markdown]
# Следующая функция группирует датасет по платформам для конкретного региона, сортирует по сумме продаж в этом регионе и суммирует все платформы, кроме топ-5 в индекс 'other'. А также строит круговую диаграмму для этих 5+1 платформ.

# %%
def top5(sign, region):
    result = df_actual.groupby(sign)[[region, 'sum_sales']].sum().sort_values(by=region, ascending=False)
    result.loc['other'] = result.iloc[5:,:].sum()
    result = result.sort_values(by=region, ascending=False).head(6)
    
    region_dict = {'na_sales':'Северная Америка', 
                   'eu_sales':'Европа', 
                   'jp_sales':'Япония', 
                   'other_sales':'Другие страны'}
    sign_dict = {'platform':'платформы', 
                 'genre':'жанры'}
    
    result.plot(
    kind='pie',
    y=region,
    figsize=(6,8)
)
    plt.title(f'Популярные {sign_dict.get(sign)} в регионе {region_dict.get(region)}', fontsize=22)
    plt.ylabel('Cумма продаж', fontsize=18);
    return result

# %%
display_side_by_side(top5('platform', 'na_sales'), top5('platform', 'eu_sales'), top5('platform', 'jp_sales'))
# Out:
#  <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>na_sales</th>
#       <th>sum_sales</th>
#     </tr>
#     <tr>
#       <th>platform</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>PS4</th>
#       <td>98.61</td>
#       <td>288.15</td>
#     </tr>
#     <tr>
#       <th>XOne</th>
#       <td>81.27</td>
#       <td>140.36</td>
#     </tr>
#     <tr>
#       <th>other</th>
#       <td>31.19</td>
#       <td>97.86</td>
#     </tr>
#     <tr>
#       <th>X360</th>
#       <td>28.30</td>
#       <td>48.22</td>
#     </tr>
#     <tr>
#       <th>3DS</th>
#       <td>22.64</td>
#       <td>86.68</td>
#     </tr>
#     <tr>
#       <th>PS3</th>
#       <td>22.05</td>
#       <td>68.18</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
# ...

# %% [markdown]
# **Северная Америка**
# * Первое место по популярности делят платформы X360 от Microsoft и PS4 от Sony
# * Далее примерно равные доли у платформ: X360, 3DS, PS3 и у других вместе взятых.
#
# **Европа**
# * Первое место по количеству продаж и почти половину рынка занимает платформа PS4 от Sony
# * 2 место у платформы X360 от Microsoft
# * Единственный регион, у которого платформа PC попала в топ-5
#
# **Япония**
# * В топе даже нет Microsoft: только Nintendo и Sony *(Японские компании)*
# * Самая популярная платформа здесь 3DS, занимает почти половину рынка
# * Оставшуюся половину делят PS4, PSV, PS3 и WiiU
#
#
# **Взглянем также на игроков из других стран**

# %%
top5('platform', 'other_sales')
# Out:
#           other_sales  sum_sales
# platform
# PS4             44.48     288.15
# XOne            12.52     140.36
# PS3              9.37      68.18
# other            7.22      97.86
# X360             4.35      48.22
# 3DS              3.68      86.68

# %% [markdown]
# **Другие страны**
# * Самая популярная платформа - PS4
# * На втором месте XOne
# * В целом максимальная схожесть с Европейским регионом

# %% [markdown]
# ### Самые популярные жанры (топ-5).

# %%
display_side_by_side(top5('genre', 'na_sales'), top5('genre', 'eu_sales'), top5('genre', 'jp_sales'))
# Out:
#  <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>na_sales</th>
#       <th>sum_sales</th>
#     </tr>
#     <tr>
#       <th>genre</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Shooter</th>
#       <td>79.02</td>
#       <td>170.94</td>
#     </tr>
#     <tr>
#       <th>Action</th>
#       <td>72.53</td>
#       <td>199.36</td>
#     </tr>
#     <tr>
#       <th>Sports</th>
#       <td>46.13</td>
#       <td>109.48</td>
#     </tr>
#     <tr>
#       <th>other</th>
#       <td>37.86</td>
#       <td>110.68</td>
#     </tr>
#     <tr>
#       <th>Role-Playing</th>
#       <td>33.47</td>
#       <td>101.44</td>
#     </tr>
#     <tr>
#       <th>Misc</th>
#       <td>15.05</td>
#       <td>37.55</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
# ...

# %%
top5('genre', 'other_sales')
# Out:
#               other_sales  sum_sales
# genre
# Action              22.57     199.36
# Shooter             21.53     170.94
# Sports              14.36     109.48
# other               10.49     110.68
# Role-Playing         8.64     101.44
# Misc                 4.03      37.55

# %% [markdown]
# **Вывод**
# * Во всех выборках (Северная Америка, Европа, Япония, другие страны) в топ-5 присутствуют жанры экшн и шутер.
# * Жанровые предпочтения игроков из Северной Америки и Европы по топ-5 почти совпадают: экшн, спорт, шутер и RPG.
# * Значительно отличаются вкусы Японцев - на первом месте игры жанра RPG, после них шутеры, а на все остальные жанры приходится около 1/3 игр.
# * В других странах картина распределения жанров в точности как в Европе.

# %% [markdown]
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
df_actual['rating'].value_counts()
# Out:
# not_used    749
# T           271
# M           265
# E           219
# E10+        185
# Name: rating, dtype: int64

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12), dpi=150)
fig.suptitle(f'Относительное распределение игр по рейтингам ESRB в разных регионах', fontsize=20)

# столбчатая диаграмма продаж для североамериканского региона
sns.barplot(
        data=df_actual,
        x='rating',
        y='na_sales',
        estimator=np.sum,
        ax=axs[0,0])
axs[0,0].set_title('Северная Америка', fontsize=18)
axs[0,0].set_xlabel('Рейтинг ESRB', fontsize=16)
axs[0,0].set_ylabel('Количество проданных копий, млн шт', fontsize=16)

# столбчатая диаграмма продаж для европейского региона
sns.barplot(
        data=df_actual,
        x='rating',
        y='eu_sales',
        estimator=np.sum,
        ax=axs[0,1]);
axs[0,1].set_title('Европа', fontsize=18)
axs[0,1].set_xlabel('Рейтинг ESRB', fontsize=16)
axs[0,1].set_ylabel('Количество проданных копий, млн шт', fontsize=16)
    
# столбчатая диаграмма продаж для японского региона
sns.barplot(
        data=df_actual,
        x='rating',
        y='jp_sales',
        estimator=np.sum,
        ax=axs[1,0]);
axs[1,0].set_title('Япония', fontsize=18)
axs[1,0].set_xlabel('Рейтинг ESRB', fontsize=16)
axs[1,0].set_ylabel('Количество проданных копий, млн шт', fontsize=16)

# столбчатая диаграмма продаж для других стран
sns.barplot(
        data=df_actual,
        x='rating',
        y='other_sales',
        estimator=np.sum,
        ax=axs[1,1]);
axs[1,1].set_title('Другие страны', fontsize=18)
axs[1,1].set_xlabel('Рейтинг ESRB', fontsize=16)
axs[1,1].set_ylabel('Количество проданных копий, млн шт', fontsize=16);

# %% [markdown]
# **Вывод**
#
# *По оси "у" на всех наших графиках отражено суммарное количество проданных игр для каждого рейтинга, но это не важно, потому что мы не сравниваем графики между собой, а сравниваем столбцы между собой в пределах одного графика для получения представления о долях.*
#
# * Портреты игроков **в Европе и Северной Америке**, а также в других странах максимально схожи:
#     * Наиболее популярны игры с рейтингом Mature (для взрослых)
#     * На втором месте с примерно одинаковой долей игры с рейтингами Everyone (для всех) и игры без рейтинга
#     * Третье место игры Teen (для подростков)
#     * На последнем месте игры с рейтингом Everyone 10+ (для всех игроков старше 10 лет)
# * Портрет игрока **в Японии** отличается:
#     * Подавляющее большинство игр не получает оценку от ESRB
#     * Игры с рейтингом ESRB по убыванию популярности: для подростков, для всех, для взрослых, для всех старше 10 лет.

# %% [markdown]
# ## Проверка гипотез
# ### Средние пользовательские рейтинги платформ Xbox One и РС одинаковые;
#
# **Нулевая гипотеза:** Средний пользовательский рейтинг платформы XOne равен среднему пользовательскому рейтингу платформы PC.
#
# **Альтернативная гипотеза:** Средние пользовательские рейтинги платформ XOne и PC отличаются.
#
# Для проверки будем использовать t-критерий для двух выборок. Дисперсии двух генеральных совокупностей считаем равными.
# За уровень значимости берем alpha = 0.05

# %%
df_actual.query('platform == "XOne"')['user_score'].dropna().shape[0]
# Out:
# 165

# %%
df_actual.query('platform == "PC"')['user_score'].dropna().shape[0]
# Out:
# 122

# %%
alpha = .05

sample1 = df_actual.query('platform == "XOne"')['user_score'].dropna()
sample2 = df_actual.query('platform == "PC"')['user_score'].dropna()

results = st.ttest_ind(
    df_actual.query('platform == "XOne"')['user_score'].dropna(),
    df_actual.query('platform == "PC"')['user_score'].dropna(),
#     equal_var=False
)

print(f'Среднее значение рейтинга критиков для платформы XOne = {round(sample1.mean(),1)}')
print(f'Среднее значение рейтинга критиков для платформы PC = {round(sample2.mean(),1)}\n')

print('p-значение:', results.pvalue)
if results.pvalue < alpha:
    print(f'На имеющихся данных на уровне значимости {alpha}\
 есть основания отвергнуть нулевую гипотезу в пользу альтернативной')
else:
    print(f'На имеющихся данных на уровне значимости {alpha}\
 нет оснований отвергнуть нулевую гипотезу в пользу альтернативной')
# Out:
# Среднее значение рейтинга критиков для платформы XOne = 6.6
# Среднее значение рейтинга критиков для платформы PC = 6.3
#
# p-значение: 0.10450507919348415
# На имеющихся данных на уровне значимости 0.05 нет оснований отвергнуть нулевую гипотезу в пользу альтернативной

# %% [markdown]
# **Вывод**
#
# Средний пользовательский рейтинг платформы XOne **равен** среднему пользовательскому рейтингу платформы PC.

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action и Sports разные
#
# **Нулевая гипотеза:** Средние пользовательские рейтинги жанров Action и Sports равны.
#
# **Альтернативная гипотеза:** Средние пользовательские рейтинги жанров Action и Sports разные.
#
# Для проверки будем использовать t-критерий для двух выборок. Дисперсии двух генеральных совокупностей считаем равными.
# За уровень значимости берем alpha = 0.05

# %%
df_actual.query('genre == "Action"')['user_score'].dropna().shape[0]
# Out:
# 297

# %%
df_actual.query('genre == "Sports"')['user_score'].dropna().shape[0]
# Out:
# 127

# %%
alpha = .05

sample1 = df_actual.query('genre == "Action"')['user_score'].dropna()
sample2 = df_actual.query('genre == "Sports"')['user_score'].dropna()

results = st.ttest_ind(
    sample1, sample2
)

print(f'Среднее значение пользовательского рейтинга для жанра "Экшн" = {round(sample1.mean(),1)}')
print(f'Среднее значение пользовательского рейтинга для жанра "Спорт" = {round(sample2.mean(),1)}\n')

print('p-значение:', results.pvalue)
if results.pvalue < alpha:
    print(f'На имеющихся данных на уровне значимости {alpha}\
 есть основания отвергнуть нулевую гипотезу в пользу альтернативной')
else:
    print(f'На имеющихся данных на уровне значимости {alpha}\
 нет оснований отвергнуть нулевую гипотезу в пользу альтернативной')
# Out:
# Среднее значение пользовательского рейтинга для жанра "Экшн" = 6.8
# Среднее значение пользовательского рейтинга для жанра "Спорт" = 5.2
#
# p-значение: 2.8711147985105864e-19
# На имеющихся данных на уровне значимости 0.05 есть основания отвергнуть нулевую гипотезу в пользу альтернативной

# %% [markdown]
# **Вывод**
#
# Cредние пользовательские рейтинги для жанров Action и Sports **действительно разные**.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **В мире существует 3 основных производителя видеоигр**:
# * Sony (Япония)
# * Nintendo (Япония)
# * Microsoft (США)
#
# **Самые продаваемые игры за период времени с 1980 по 2016 год были выпущены для платформ**:
# 1. PS2
# 2. X360
# 3. PS3
# 4. Wii
# 5. DS
# 6. PS
#
# По результатам проекта выявлены следующие факты:
# * **Среднее время жизни платформы** около 6-8 лет;
# * **Пик продаж** наступает спустя 5 лет от выхода платформы на рынок;
#     * Пик продаж за всё время существования игр для приставок был достигнут в 2008-2010 годах и с тех пор тренд продаж только на снижение;
# * Появление платформы следующего поколения быстро отражается на продажах игр для платформы предыдущего поколения (например, падение продаж для PS2 при выходе PS3);
# * **Корреляция между оценками пользователей и продажами** отсутствует. Ориентироваться на оценки пользователей в планировании бизнес-плана не стоит;
# * **Корреляция между оценками критиков и продажами** слабая положительная, можно брать во внимание при планировании;
# * В качестве **актуальногго периода для исследования** был выбран трёхлетний период релиза игр с 2014 по 2016
# * **Самые популярные жанры игр** по количеству продаж актуальный период:
#     1. Шутеры;
#     2. Спортивные игры;
#     3. Платформеры;
# * Наименее прибыльные жанры: паззлы, приключения и стратегия
#
# * **Портрет пользователя каждого региона**
#     * Северная Америка:
#         * **Самые популярные платформы** с примерно равными долями рынка: X360 от Microsoft и PS4 от Sony
#         * **Самые популярные жанры:** экшн, спорт, шутер и RPG, *разнообразный*
#
#     * Европа:
#         * Первое место по количеству продаж и почти половину рынка занимает платформа PS4 от Sony
#         * Второе место у платформы X360 от Microsoft
#         * **Самый популярный жанр** - экшн, спорт, шутер и RPG, *гонки*
#         * На втором месте тоже спорт и шутер
#
#     * Япония:
#         * В топ-5 платформ даже нет Microsoft: только Nintendo и Sony.
#         * Самая популярная платформа здесь 3DS, занимает почти половину рынка
#         * Оставшуюся половину делят PS4, PSV, PS3 и WiiU
#         * **Самый популярный жанр** - RPG
#         * На втором месте шутеры, а на все остальные жанры приходится около 1/3 игр.
#
# * **Рейтинг ESRB**:
#     * ***В Северной Америке и Европе*** наиболее популярны игры с рейтингом для взрослых, на втором месте игры для всех и игры без рейтинга, на 3-4 месте игры для подростков и для всех игроков старше 10 лет.
#     * ***В Японии*** картина несколько иная: большая часть игр вообще не имеет рейтинга, среди оценённых ESRB убывающая последовательность следующая: для подростков, для всех, для взрослых, для всех старше 10 лет.
#
# Таким образом, мы видим, что в разных регионах популярны разные жанры и разные платформы, самый особенный и отличающийся регион - Япония.
#
# **К сожалению, основываясь на данных настоящего исследования, не представляется возможным выявить потенциально популярный в 2017 году продукт и рекомендовать проведение рекламных кампаний в этом направлении. Вероятно, снижение популярности игр для игровых платформ связано с бурным развитием игр для мобильных операционных систем (В первую очередь для iOS и Android).**
